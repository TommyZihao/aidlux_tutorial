# %% [markdown]
# # PyTorch转ONNX
#
# 同济子豪兄 2023-6-25

# %% [markdown]
# ## 只需直接下载子豪兄准备好的两个ONNX模型即可

# %%
# !wget https://zihao-tutorial.obs.cn-east-3.myhuaweicloud.com/aidlux/ckpt/resnet18_imagenet.onnx -P ckpt
# !wget https://zihao-tutorial.obs.cn-east-3.myhuaweicloud.com/aidlux/ckpt/resnet18_fruit30.onnx -P ckpt

# %% [markdown]
# ## PyTorch转ONNX
#
# - `resnet18_imagenet.onnx`：PyTorch官方预训练模型-ImageNet1000类图像分类模型 转ONNX
#
# - `resnet18_fruit30.onnx`：自己训练得到的30类水果图像分类模型 转ONNX

# %% [markdown]
# ## 扩展阅读
#
# PyTorch图像分类模型训练全流程：https://space.bilibili.com/1900783/channel/collectiondetail?sid=606800
#
# PyTorch转ONNX教程：https://www.bilibili.com/video/BV1cM4y187Xc
